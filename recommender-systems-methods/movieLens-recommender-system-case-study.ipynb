# %% [markdown]
# # Hybrid Recommender System
#
# In this project, 10 movies will be recommended for the user whose ID is given, using item-based and user-based recommender methods.
#
# The dataset was provided by **MovieLens**, a movie recommendation service. It contains the rating scores for these movies along with the movies. It contains 2,000,0263 ratings across 27,278 movies. This data set was created on October 17, 2016. Includes 138,493 users and data from 09 January 1995 to 31 March 2015. Users are randomly selected. It is known that all selected users voted for at least 20 movies.
#
# ### Data
#
# *movieId* : Unique movie number.<br>
# *title* : Movie name<br>
# *genres* : Genre<br>
# *userid* : Unique user number. (UniqueID)<br>
# *rating* : The rating given to the movie by the user<br>
# *timestamp* : Evaluation date<br>

# %%
# libraries
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option("display.max_columns",None)
pd.set_option("display.width",500)
sns.set(rc={"figure.figsize":(12,12)})

# %% [markdown]
# # User Based Recommendation

# %%
movie = pd.read_csv("datas/movie.csv")
rating = pd.read_csv("datas/rating.csv")

# %%
movie.head()
# Out:
#    movieId                               title                                       genres
# 0        1                    Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2                      Jumanji (1995)                   Adventure|Children|Fantasy
# 2        3             Grumpier Old Men (1995)                               Comedy|Romance
# 3        4            Waiting to Exhale (1995)                         Comedy|Drama|Romance
# 4        5  Father of the Bride Part II (1995)                                       Comedy

# %%
rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
data = movie.merge(rating, on="movieId",how="left")
data.head()
# Out:
#    movieId             title                                       genres  userId  rating            timestamp
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy     3.0     4.0  1999-12-11 13:36:47
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy     6.0     5.0  1997-03-13 17:50:52
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy     8.0     4.0  1996-06-05 13:37:51
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy    10.0     4.0  1999-11-25 02:44:47
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy    11.0     4.5  2009-01-02 01:13:41

# %%
data["title"].value_counts()
# Out:
# Pulp Fiction (1994)                          67310
# Forrest Gump (1994)                          66172
# Shawshank Redemption, The (1994)             63366
# Silence of the Lambs, The (1991)             63299
# Jurassic Park (1993)                         59715
#                                              ...
# Rapture (Arrebato) (1980)                        1
# Education of Mohammad Hussein, The (2013)        1
# Satanas (2007)                                   1
# Psychosis (2010)                                 1
# Innocence (2014)                                 1
# Name: title, Length: 27262, dtype: int64

# %%
comment_counts = pd.DataFrame(data["title"].value_counts())
rare_movies = comment_counts[comment_counts["title"] <= 10000].index # movies with less comments/rates than 10000

# %%
comment_counts.head() # most commented movies
# Out:
#                                   title
# Pulp Fiction (1994)               67310
# Forrest Gump (1994)               66172
# Shawshank Redemption, The (1994)  63366
# Silence of the Lambs, The (1991)  63299
# Jurassic Park (1993)              59715

# %%
rare_movies[:20]
# Out:
# Index(['Ronin (1998)', 'My Best Friend's Wedding (1997)', 'Flintstones, The (1994)', 'Copycat (1995)', 'Space Jam (1996)', 'Harry Potter and the Goblet of Fire (2005)', 'Junior (1994)', 'Perfect Storm, The (2000)', 'Swingers (1996)', 'Fatal Attraction (1987)', 'Star Trek: The Motion Picture (1979)', 'Avatar (2009)', 'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2) (2002)', 'Brady Bunch Movie, The (1995)', 'Raging Bull (1980)', 'My Fair Lady (1964)', 'Bowfinger (1999)', 'I, Robot (2004)',
#        'Pirates of the Caribbean: Dead Man's Chest (2006)', 'Bridges of Madison County, The (1995)'],
#       dtype='object')

# %%
common_movies = data[~data["title"].isin(rare_movies)] # this leaves popular movies

# A pivot table has been created for the dataframe in the index, where the userIDs, 
# the movie names in the columns, and the ratings as values.

user_movie_df = common_movies.pivot_table(index=["userId"],
                                   columns=["title"],
                                   values="rating")
user_movie_df = user_movie_df.astype(np.float32)
user_movie_df.head(10)
# Out:
# title   10 Things I Hate About You (1999)  12 Angry Men (1957)  2001: A Space Odyssey (1968)  28 Days Later (2002)  300 (2007)  A.I. Artificial Intelligence (2001)  Abyss, The (1989)  Ace Ventura: Pet Detective (1994)  Ace Ventura: When Nature Calls (1995)  Addams Family Values (1993)  Adventures of Priscilla, Queen of the Desert, The (1994)  African Queen, The (1951)  Air Force One (1997)  Airplane! (1980)  Aladdin (1992)  Alien (1979)  Alien: Resurrection (1997)  Aliens (1986)  \
# userId
# 1.0                                   NaN                  NaN                           3.5                   3.5         NaN                                  NaN                NaN                                NaN                                    NaN                          NaN                                                NaN                               NaN                   NaN               NaN             NaN           4.0                         NaN            4.0
# ...

# %% [markdown]
# As can be seen from this pivot table, the first user watched the movie *2001: A Space Odyssey (1968)* and gave **3.5** points. **NaN** values indicate that the user did not watch and evaluate that movie.

# %% [markdown]
# A random userId is chosen. A new dataframe consisting of observation units of the selected user has been created. The movies that the selected users voted are assigned to a list.

# %%
def user_based_recommender(random_user,user_movie_df,ratio = 0.90, cor_th =0.65, score=3.5):
    
    # Accessing Data and Ids of Other Users Watching the Same Movies
    random_user_df = user_movie_df[user_movie_df.index == random_user]
    movies_watched = random_user_df.columns[random_user_df.notna().any()].tolist()
    
    movies_watched_df = user_movie_df[movies_watched]
    
    user_movie_count = movies_watched_df.T.notnull().sum()
    user_movie_count= user_movie_count.reset_index()
    user_movie_count.columns = ["userId","movie_count"]
    
    percentage = len(movies_watched) * ratio
    
    users_with_same_movies = user_movie_count[user_movie_count["movie_count"] > percentage]["userId"]

    # Determining the Users to be Suggested and Most Similar Users
    final_df = pd.concat([movies_watched_df[movies_watched_df.index.isin(users_with_same_movies)],
                         random_user_df[movies_watched]])
    
    correlation_df = final_df.T.corr().unstack().sort_values().drop_duplicates()
    correlation_df = pd.DataFrame(correlation_df,columns=["corr"])
    correlation_df.index.names = ["user_id_1","user_id_2"]
    correlation_df = correlation_df.reset_index()
    
    top_users = correlation_df[(correlation_df["user_id_1"] == random_user) & (correlation_df["corr"] >= cor_th)][["user_id_2","corr"]].reset_index(drop=True)
        
    top_users = top_users.sort_values(by="corr",ascending=False)
    top_users.rename(columns={"user_id_2":"userId"},inplace=True)
    
    rating = pd.read_csv("datas/rating.csv")
    top_users_ratings = top_users.merge(rating[["userId","movieId","rating"]], how="inner")
    top_users_ratings["weighted_rating"] = top_users_ratings["corr"] * top_users_ratings["rating"]
    
    recommendation_df = top_users_ratings.groupby("movieId").agg({"weighted_rating":"mean"})
    recommendation_df = recommendation_df.reset_index()
    
    movies_to_be_recommended = recommendation_df[recommendation_df["weighted_rating"] > score].sort_values("weighted_rating",
                                                                                                           ascending=False)
    
    movie = pd.read_csv("datas/movie.csv")
    
    recommended_user_based_df = movies_to_be_recommended.merge(movie[["movieId","title"]])
    recommended_user_based_df = recommended_user_based_df.loc[~recommended_user_based_df["title"].isin(movies_watched)][:5]
    
    return recommended_user_based_df

# %%
random_user = int(pd.Series(user_movie_df.index).sample(1).values)
random_user
# Out:
# 48078

# %%
user_based_df = user_based_recommender(random_user,user_movie_df)
user_based_df
# Out:
#     movieId  weighted_rating                            title
# 2      1343              5.0                 Cape Fear (1991)
# 5      1459              5.0            Absolute Power (1997)
# 10     1769              5.0  Replacement Killers, The (1998)
# 11     2058              5.0           Negotiator, The (1998)
# 12     2273              5.0                 Rush Hour (1998)

# %%
def bring_movies(random_user,user_movie_df):
    random_user_df = user_movie_df[user_movie_df.index == random_user]
    movies_watched = random_user_df.columns[random_user_df.notna().any()].tolist()
    
    return movies_watched

# %%
movies_watched_by_user = bring_movies(random_user,user_movie_df)
movies_watched_by_user
# Out:
# ['Ace Ventura: When Nature Calls (1995)',
#  'Arachnophobia (1990)',
#  'Armageddon (1998)',
#  'Basic Instinct (1992)',
#  'Braveheart (1995)',
#  'Broken Arrow (1996)',
#  'Casino (1995)',
#  'Clear and Present Danger (1994)',
#  'Close Encounters of the Third Kind (1977)',
#  'Con Air (1997)',
#  'Conspiracy Theory (1997)',
#  'Die Hard 2 (1990)',
#  'E.T. the Extra-Terrestrial (1982)',
#  'Enemy of the State (1998)',
#  'Eraser (1996)',
#  'Face/Off (1997)',
#  'Fargo (1996)',
#  'Firm, The (1993)',
#  'Fugitive, The (1993)',
#  'Game, The (1997)',
#  'Gattaca (1997)',
#  'Ghost (1990)',
#  'Heat (1995)',
#  'Hunt for Red October, The (1990)',
#  'In the Line of Fire (1993)',
#  'Lost World: Jurassic Park, The (1997)',
#  'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)',
#  'Maltese Falcon, The (1941)',
#  'Matrix, The (1999)',
#  'Maverick (1994)',
#  'Mummy, The (1999)',
#  'Primal Fear (1996)',
#  'Ransom (1996)',
#  'Rock, The (1996)',
# ...

# %% [markdown]
# As you can see, the sample user has watched movies such as **Jurassic Park**, **X-Men**, and **The Truman Show**, which are mostly fantasy, comedy and action genres. For this reason, the first recommendation comes from the action-fantasy combination that the user mostly watches, while the comedy-drama movie recommendation takes place in the second place.

# %% [markdown]
# ---------
# # Item Based Recommendation

# %%
def item_based_recommender(movie_name, user_movie_df, head=10):
    
    movie = user_movie_df[movie_name]
    
    return user_movie_df.corrwith(movie).sort_values(ascending=False).head(head)

# %%
movies_from_item_based = item_based_recommender('Gone with the Wind (1939)',user_movie_df,20).reset_index()
recommended_item_based_df = movies_from_item_based.loc[~movies_from_item_based["title"].isin(movies_watched_by_user)][1:6]

# %%
recommended_item_based_df
# Out:
#                                     title         0
# 1                Wizard of Oz, The (1939)  0.404079
# 2  Snow White and the Seven Dwarfs (1937)  0.402325
# 3              Sound of Music, The (1965)  0.391269
# 4              Little Mermaid, The (1989)  0.343236
# 5                       Casablanca (1942)  0.340200

# %%
hybrid_rec_df = pd.concat([user_based_df["title"], recommended_item_based_df["title"]]).reset_index(drop=True)

# %%
hybrid_rec_df
# Out:
# 0                          Cape Fear (1991)
# 1                     Absolute Power (1997)
# 2           Replacement Killers, The (1998)
# 3                    Negotiator, The (1998)
# 4                          Rush Hour (1998)
# 5                  Wizard of Oz, The (1939)
# 6    Snow White and the Seven Dwarfs (1937)
# 7                Sound of Music, The (1965)
# 8                Little Mermaid, The (1989)
# 9                         Casablanca (1942)
# Name: title, dtype: object
